# %%
# !nvidia-smi
# Out:
# Tue Jan 16 19:19:33 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   69C    P0              32W /  70W |    657MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)

# %%
import json
import os
import glob

import random
import numpy as np
import pandas as pd

from tqdm import tqdm

from pathlib import Path

import torch
from torch.utils.data import Dataset, DataLoader, RandomSampler, SequentialSampler
from sklearn.model_selection import train_test_split
from transformers import AutoConfig, AutoModelWithLMHead, AutoTokenizer, GPT2LMHeadModel, GPT2Config
from transformers import AdamW

from torch.nn.functional import softmax
from nltk.translate.bleu_score import corpus_bleu

from IPython import display

# %% [markdown]
# # (a) Process the Data

# %%
import re
from sklearn.model_selection import train_test_split

# Assuming you have a file containing the poems
poems_path = 'ferdousi.txt'

# Read and preprocess the data
with open(poems_path, 'r', encoding='utf-8') as file:
    poems_text = file.read()

# Split the poems into verses
verses = re.split('\n', poems_text)
verses = [verse.strip() for verse in verses if verse.strip()]

# Create input-output pairs (line pairs)
pairs = [(verses[i], verses[i+1], verses[i+2], verses[i+3]) for i in range(0, len(verses)-3, 2)]

# Split the data into training and test sets
train_pairs, test_pairs = train_test_split(pairs, test_size=0.1, random_state=42)

# %%
print(len(train_pairs))
print(len(test_pairs))
# Out:
# 20660
# 2296

# %% [markdown]
# # (b) Build Data Loaders

# %%
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer

# Use the pre-trained GPT2 tokenizer
model_name_or_path = "HooshvareLab/gpt2-fa"
#tokenizer = AutoTokenizer.from_pretrained(model_name_or_path)
tokenizer = AutoTokenizer.from_pretrained(model_name_or_path, bos_token='', eos_token='', pad_token='')

class PoetryDataset(Dataset):
    def __init__(self, pairs, tokenizer, max_length=256):
        self.pairs = pairs
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.pairs)

    def __getitem__(self, idx):
        input_verse1, input_verse2, target_verse1, target_verse2 = self.pairs[idx]

        # Tokenize input and target verses
        input_encoding = self.tokenizer(input_verse1 + " " + input_verse2, truncation=True, max_length=self.max_length, padding="max_length", return_tensors="pt")
        target_encoding = self.tokenizer(target_verse1 + " " + target_verse2, truncation=True, max_length=self.max_length, padding="max_length", return_tensors="pt")

        return {
            'input_ids': input_encoding['input_ids'].squeeze(),
            'attention_mask_input': input_encoding['attention_mask'].squeeze(),
            'labels': target_encoding['input_ids'].squeeze(),
            'attention_mask_target': target_encoding['attention_mask'].squeeze()
        }
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
# Create data loaders
train_dataset = PoetryDataset(train_pairs, tokenizer)
test_dataset = PoetryDataset(test_pairs, tokenizer)

batch_size = 8
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # (c) Load Pre-trained Model and Fine-tune

# %%
from transformers import GPT2LMHeadModel, GPT2Config, AdamW

# Load pre-trained GPT2 model
model = GPT2LMHeadModel.from_pretrained(model_name_or_path)
model.resize_token_embeddings(len(tokenizer))
# Out:
# Embedding(42001, 768)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(42001, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-11): 12 x GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=42001, bias=False)
# )

# %%
# Fine-tune the model
optimizer = AdamW(model.parameters(), lr=5e-5)
num_epochs = 1

for epoch in range(num_epochs):
    model.train()
    total_loss = 0

    for batch in train_loader:
        input_ids = batch['input_ids'].to(device)
        attention_mask_input = batch['attention_mask_input'].to(device)
        labels = batch['labels'].to(device)
        attention_mask_target = batch['attention_mask_target'].to(device)

        # Forward pass
        outputs = model(input_ids, attention_mask=attention_mask_input, labels=labels, attention_mask_target=attention_mask_target)
        loss = outputs.loss

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    average_loss = total_loss / len(train_loader)
    print(f"Epoch {epoch + 1}/{num_epochs}, Average Loss: {average_loss}")

# Evaluate the model on the test set
model.eval()
test_loss = 0

for batch in test_loader:
    input_ids = batch['input_ids'].to(device)
    attention_mask_input = batch['attention_mask_input'].to(device)
    labels = batch['labels'].to(device)

    with torch.no_grad():
        outputs = model(input_ids, attention_mask=attention_mask_input, labels=labels)
        test_loss += outputs.loss.item()

average_test_loss = test_loss / len(test_loader)
print(f"Average Test Loss: {average_test_loss}")


# Save the fine-tuned model if needed
model.save_pretrained("fine_tuned_model")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Epoch 1/1, Average Loss: 0.44028428139217685
# Average Test Loss: 0.3559824666495107

# %% [markdown]
# # (d) Generate Sentences and Evaluate on Test Set

# %%
from nltk.translate.bleu_score import corpus_bleu

def generate_sentence(model, tokenizer, input_sentence, max_length=256, temperature=1.0):
    model.eval()
    with torch.no_grad():
        input_ids = tokenizer.encode(input_sentence, return_tensors="pt").to(device)

        # Attention mask for generation
        attention_mask = torch.ones_like(input_ids).to(device)

        # Generate sentence
        output_ids = model.generate(
            input_ids,
            max_length=max_length,
            temperature=temperature,
            attention_mask=attention_mask
        )

        # Filter out input tokens from generated tokens
        generated_sentence = tokenizer.decode(output_ids[0, input_ids.shape[1]:], skip_special_tokens=True)

    return generated_sentence


# Evaluate on the test set using BLEU score
references = [test_pair[2] + " " + test_pair[3] for test_pair in test_pairs]  # Target verses in the test set

generated_sentences = []
for test_pair in test_pairs:
    input_verse1, input_verse2, target_verse1, target_verse2 = test_pair
    input_sentence = input_verse1 + " " + input_verse2
    target_sentence = target_verse1 + " " + target_verse2
    print("-------------------------new test-----------------------")
    print(f"Input Sentence: {input_sentence}")
    generated_sentence = generate_sentence(model, tokenizer, input_sentence)
    print(f"Generated Sentence: {generated_sentence}")
    print(f"Target Sentence: {target_sentence}")
    generated_sentences.append(generated_sentence)

bleu_score = corpus_bleu([[ref.split()] for ref in references], [gen.split() for gen in generated_sentences])
print(f"BLEU Score on Test Set: {bleu_score}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Generated Sentence: ستاره بدان دشت نظاره بود که این لشکر از جنگ بیچاره بود
# Target Sentence: بگشتیم گرد دژ ایدر بسی ندیدیم جز کینه درمان کسی
# -------------------------new test-----------------------
# Input Sentence: غمی گشت رستم ز گفتار اوی بر شاه کاووس بنهاد روی
# Generated Sentence: غمی گشت رستم ز گفتار اوی بر شاه کاووس بنهاد روی
# Target Sentence: چو کاووس کی پهلوان را بدید بر خویش نزدیک جایش گزید
# -------------------------new test-----------------------
# Input Sentence: همی گفت زار این جهانبین من سوار سرافراز رویین من
# Generated Sentence: همی گفت زار این جهانبین من سوار سرافراز رویین من
# Target Sentence: جهانجوی لهاک و فرشیدورد سواران و گردان روز نبرد
# -------------------------new test-----------------------
# Input Sentence: همه رزمگه دخمه ها ساختند ازان کشتگان چو بپرداختند
# Generated Sentence: همه رزمگه دخمه ها ساختند ازان کشتگان چو بپرداختند
# Target Sentence: ز چیزی که بود اندران رزمگاه ببخشید شاه جهان بر سپاه
# -------------------------new test-----------------------
# Input Sentence: بر ایشان در گنج بسته مدار ببخش و بترس از بد روزگار
# Generated Sentence: بر ایشان در گنج بسته مدار ببخش و بترس از بد روزگار
# Target Sentence: دگر گنج کش نام بادآورست پر از افسر و زیور و گوهرست
# -------------------------new test-----------------------
# Input Sentence: خردمند پیران که در نامه یاد چه آورد وز پند نیکو چه داد
# Generated Sentence: خردمند پیران که در نامه یاد چه آورد وز پند نیکو چه داد
# Target Sentence: برویین چنین گفت پس پهلوان که ای پور سالار و فرخ جوان
# -------------------------new test-----------------------
# Input Sentence: ببیژن چنین گفت گستهم زود که لختی عنانت بباید بسود
# Generated Sentence: ببیژن چنین گفت گستهم زود که لختی عنانت بباید بسود
# Target Sentence: برستم بگویی که چندین مایست بجنبان عنان با سواری دویست
# -------------------------new test-----------------------
# Input Sentence: ز هوشنگ و طهمورث و جمشید یکی مهره بد خستگان را امید
# Generated Sentence: ز هوشنگ و طهمورث و جمشید یکی مهره بد خستگان را امید
# Target Sentence: رسیده بمیراث نزدیک شاه ببازوش برداشتی سال و ماه
# -------------------------new test-----------------------
# Input Sentence: تو دانسته ای درد و تیمار من ز بهر تو با شاه پیگار من
# Generated Sentence: تو دانسته ای درد و تیمار من ز بهر تو با شاه پیگار من
# Target Sentence: سزد گر من از چنگ این اژدها به بخت و به فر تو یابم رها
# -------------------------new test-----------------------
# Input Sentence: چنین گفت کز پاک مام و پدر یکی شاخ شایسته آمد به بر
# Generated Sentence: چنین گفت کز پاک مام و پدر یکی شاخ شایسته آمد به بر
# Target Sentence: می روشن آمد ز پرمایه جام مر آن چهر دارد منوچهر نام
# -------------------------new test-----------------------
# Input Sentence: گروهی ز آهنگران رنجه کرد ز پولاد بر هر سوی پنجه کرد
# Generated Sentence: گروهی ز آهنگران رنجه کرد ز پولاد بر هر سوی پنجه کرد
# Target Sentence: ببستند بر نیزه های دراز که هر کس که رفتی بر دژ فراز
# -------------------------new test-----------------------
# Input Sentence: گرانمایه را نام هوشنگ بود تو گفتی همه هوش و فرهنگ بود
# Generated Sentence: گرانمایه را نام هوشنگ بود تو گفتی همه هوش و فرهنگ بود
# Target Sentence: به نزد نیا یادگار پدر نیا پروریده مراو را به بر
# -------------------------new test-----------------------
# Input Sentence: کسی را که رستم بود پهلوان سزد گر بماند همیشه جوان
# Generated Sentence: کسی را که رستم بود پهلوان سزد گر بماند همیشه جوان
# Target Sentence: پرستنده چون تو ندارد سپهر ز تو بخت هرگز مبراد مهر
# -------------------------new test-----------------------
# Input Sentence: چنین پاسخ آورد هومان بدوی که بیشی نه خوبست بیشی مجوی
# Generated Sentence: چنین پاسخ آورد هومان بدوی که بیشی نه خوبست بیشی مجوی
# Target Sentence: گر ایدونک بیچاره ای را زمان بدست تو آمد مشو در گمان
# -------------------------new test-----------------------
# Input Sentence: ازان پس بسازید سهراب را ببندید یک شب برو خواب را
# Generated Sentence: ازان پس بسازید سهراب را ببندید یک شب برو خواب را
# Target Sentence: برفتند بیدار دو پهلوان به نزدیک سهراب روشن روان
# -------------------------new test-----------------------
# Input Sentence: یکی تاج زرین نگارش گهر نهاد از بر تارک زال زر
# Generated Sentence: یکی تاج زرین نگارش گهر نهاد از بر تارک زال زر
# Target Sentence: به کابل رسیدند خندان و شاد سخنهای دیرینه کردند یاد
# -------------------------new test-----------------------
# Input Sentence: هران چیز کز راه بیداد دید هر آن بوم و برکان نه آباد دید
# Generated Sentence: هران چیز کز راه بیداد دید هر آن بوم و برکان نه آباد دید
# Target Sentence: به نیکی ببست از همه دست بد چنانک از ره هوشیاران سزد
# -------------------------new test-----------------------
# Input Sentence: چنین کردشان ایزد دادگر نه رای و نه دانش نه پای و نه پر
# Generated Sentence: چنین کردشان ایزد دادگر نه رای و نه دانش نه پای و نه پر
# Target Sentence: بدو دست یازم که او یار بس ز گیتی نخواهیم فریادرس
# -------------------------new test-----------------------
# Input Sentence: یکی آنک هر کس که از خون شاه بگسترد بر خیره این رزمگاه
# Generated Sentence: یکی آنک هر کس که از خون شاه بگسترد بر خیره این رزمگاه
# Target Sentence: ببندی فرستی بر شهریار سزد گر نفرماید این کارزار
# -------------------------new test-----------------------
# Input Sentence: همه نامداران شدند انجمن چو دستان و چون قارن رزم زن
# Generated Sentence: همه نامداران شدند انجمن چو دستان و چون قارن رزم زن
# Target Sentence: چو کشواد و خراد و برزین گو فشاندند گوهر بران تاج نو
# -------------------------new test-----------------------
# Input Sentence: که توران شه آن ناجوانمرد مرد نگه کن که با شاه ایران چه کرد
# Generated Sentence: که توران شه آن ناجوانمرد مرد نگه کن که با شاه ایران چه کرد
# Target Sentence: سوی روی پوشیدگان سپاه سپاهی فرستاد بی مر به راه
# -------------------------new test-----------------------
# Input Sentence: به نزد سیاوش خرامید زود برو بر شمرد آن کجا رفته بود
# Generated Sentence: به نزد سیاوش خرامید زود برو بر شمرد آن کجا رفته بود
# Target Sentence: نشستند شادان دل آن شب بهم به باده بشستند جان را ز غم
# -------------------------new test-----------------------
# Input Sentence: سپارد بگنج تو از گنج خویش همی باز خرد بدین رنج خویش
# Generated Sentence: سپارد بگنج تو از گنج خویش همی باز خرد بدین رنج خویش
# Target Sentence: هران شهر کز مرزایران نهی همی کرد خواهد ز ترکان تهی
# -------------------------new test-----------------------
# Input Sentence: میان دو صف شیده او را بدید یکی باد سرد از جگر بر کشید
# Generated Sentence: میان دو صف شیده او را بدید یکی باد سرد از جگر بر کشید
# Target Sentence: بدو گفت پور سیاوش رد توی ای پسندیدهٔ پرخرد
# -------------------------new test-----------------------
# Input Sentence: مرا پادشاهی آباد هست همان گنج و مردی و نیروی دست
# Generated Sentence: مرا پادشاهی آباد هست همان گنج و مردی و نیروی دست
# Target Sentence: سه فرزند شایستهٔ تاج و گاه اگر داستان را بود گاه ماه
# -------------------------new test-----------------------
# Input Sentence: نشستنگهی نو بیاراستند ز شاه نو آیین خبر خواستند
# Generated Sentence: نشستنگهی نو بیاراستند ز شاه نو آیین خبر خواستند
# Target Sentence: بجستند هر گونه ای آگهی ز دیهیم و ز تخت شاهنشهی
# -------------------------new test-----------------------
# Input Sentence: زواره بیامد خلیده روان که چون بود امروز بر پهلوان
# Generated Sentence: زواره بیامد خلیده روان که چون بود امروز بر پهلوان
# Target Sentence: ازو خوردنی خواست رستم نخست پس آنگه ز اندیشگان دل بشست
# -------------------------new test-----------------------
# Input Sentence: طلایه ز هر سو برون تاختند بهر پرده ای پاسبان ساختند
# Generated Sentence: طلایه ز هر سو برون تاختند بهر پرده ای پاسبان ساختند
# Target Sentence: چو برزد سر از برج خرچنگ شید جهان گشت چون روی رومی سپید
# -------------------------new test-----------------------
# Input Sentence: چه گفت آن خردمند بسیار هوش که با اختر بد به مردی مکوش
# Generated Sentence: چه گفت آن خردمند بسیار هوش که با اختر بد به مردی مکوش
# Target Sentence: چنین گفت زان پس به افراسیاب که ای پرهنر شاه با جاه و آب
# -------------------------new test-----------------------
# Input Sentence: جهاندار برپای بد هفت روز بهشتم چو بفروخت گیتی فروز
# Generated Sentence: جهاندار برپای بد هفت روز بهشتم چو بفروخت گیتی فروز
# Target Sentence: ز در پرده برداشت سالار بار نشست از بر تخت زر شهریار
# -------------------------new test-----------------------
# Input Sentence: نخستین برادرش کهتر به سال که در مردمی کس ندارد همال
# Generated Sentence: نخستین برادرش کهتر به سال که در مردمی کس ندارد همال
# Target Sentence: ز گیتی پرستندهٔ فر و نصر زید شاد در سایهٔ شاه عصر
# -------------------------new test-----------------------
# Input Sentence: همی پوست از باد بر من بسوخت زمان تا زمان خاک چشمم بدوخت
# Generated Sentence: همی پوست از باد بر من بسوخت زمان تا زمان خاک چشمم بدوخت
# Target Sentence: همی خواندندی مرا پور سام به اورنگ بر سام و من در کنام
# -------------------------new test-----------------------
# Input Sentence: سدیگر که گفتی ز یزدان پاک نبینم بدلت اندرون بیم و باک
# Generated Sentence: سدیگر که گفتی ز یزدان پاک نبینم بدلت اندرون بیم و باک
# Target Sentence: ندانی کزین خیره خون ریختن گرفتار کردی بفرجام تن
# -------------------------new test-----------------------
# Input Sentence: که لشکر بنزدیک جیحون رسید همه روی کشور سپه گسترید
# Generated Sentence: که لشکر بنزدیک جیحون رسید همه روی کشور سپه گسترید
# Target Sentence: بدان درد و زاری سپه را بخواند ز پیران فراوان سخنها برآند
# -------------------------new test-----------------------
# Input Sentence: که اویست جاوید فریادرس بسختی نگیرد جز او دست کس
# Generated Sentence: که اویست جاوید فریادرس بسختی نگیرد جز او دست کس
# Target Sentence: اگر زنده گردد تن مرده مرد جهاندار گستهم را زنده کرد
# -------------------------new test-----------------------
# Input Sentence: که شهر و دلیران و لشکر گمان به دیگر سخنها برند این زمان
# Generated Sentence: که شهر و دلیران و لشکر گمان به دیگر سخنها برند این زمان
# Target Sentence: کزین ترک ترسنده شد سرفراز همی رفت زین گونه چندی به راز
# -------------------------new test-----------------------
# Input Sentence: به رستم چنین گفت کافراسیاب چو از تو خبر یافت اندر شتاب
# Generated Sentence: به رستم چنین گفت کافراسیاب چو از تو خبر یافت اندر شتاب
# Target Sentence: یکی یادگاری به نزدیک شاه فرستاد با من کنون در به راه
# -------------------------new test-----------------------
# Input Sentence: به شبگیر گردان به میدان شدند گرازان و تازان و خندان شدند
# Generated Sentence: به شبگیر گردان به میدان شدند گرازان و تازان و خندان شدند
# Target Sentence: چنین گفت پس شاه توران بدوی که یاران گزینیم در زخم گوی
# -------------------------new test-----------------------
# Input Sentence: پذیره فرستیم گردی دمان ببینیم تا بر که گردد زمان
# Generated Sentence: پذیره فرستیم گردی دمان ببینیم تا بر که گردد زمان
# Target Sentence: وزیشان بتندی نجویید جنگ بباید یک امروز کردن درنگ
# -------------------------new test-----------------------
# Input Sentence: بد آن منکری باره مانده بپای بدان نیزه ها برگرفته ز جای
# Generated Sentence: بد آن منکری باره مانده بپای بدان نیزه ها برگرفته ز جای
# Target Sentence: پس آلود بر چوب نفط سیاه بدین گونه فرمود بیدار شاه
# -------------------------new test-----------------------
# Input Sentence: نبدمان بکار سیاوش گناه ببرد اهرمن شاه را دل ز راه
# Generated Sentence: نبدمان بکار سیاوش گناه ببرد اهرمن شاه را دل ز راه
# Target Sentence: که توران ز ایران همه پر غمست زن و کودک خرد در ماتمست
# -------------------------new test-----------------------
# Input Sentence: که آن بودنی بود از کردگار نیامد بدین بد کس آموزگار
# Generated Sentence: که آن بودنی بود از کردگار نیامد بدین بد کس آموزگار
# Target Sentence: که کیخسرو از من نگیرد فروغ نبیره مخوانش که باشد دروغ
# -------------------------new test-----------------------
# Input Sentence: شنیدم پیام از کران تا کران ز بیدار دل زنگهٔ شاوران
# Generated Sentence: شنیدم پیام از کران تا کران ز بیدار دل زنگهٔ شاوران
# Target Sentence: غمی شد دلم زانک شاه جهان چنین تیز شد با تو اندر نهان
# -------------------------new test-----------------------
# Input Sentence: برین کینه آرامش و خواب نیست همی چون دو چشمم به جوی آب نیست
# Generated Sentence: برین کینه آرامش و خواب نیست همی چون دو چشمم به جوی آب نیست
# Target Sentence: روان چنان شهریار جهان درخشنده بادا میان مهان
# -------------------------new test-----------------------
# Input Sentence: خروشی یر آمد تو گفتی که ابر همی خون چکاند ز چشم هژبر
# Generated Sentence: خروشی یر آمد تو گفتی که ابر همی خون چکاند ز چشم هژبر
# Target Sentence: همی بودش اندر بخارا درنگ همی خواست کایند شیران به جنگ
# -------------------------new test-----------------------
# Input Sentence: چو رستم بگیرد سر گاه ما بیکبارگی گم شود راه ما
# Generated Sentence: چو رستم بگیرد سر گاه ما بیکبارگی گم شود راه ما
# Target Sentence: کنونش گمان آنک ما نشنویم چنین کار در جنگ کیخسرویم
# -------------------------new test-----------------------
# Input Sentence: به مهر و به داد و به خوی و خرد زمانه همی از تو رامش برد
# Generated Sentence: به مهر و به داد و به خوی و خرد زمانه همی از تو رامش برد
# Target Sentence: همه گنج گیتی به چشم تو خوار مبادا ز تو نام تو یادگار
# -------------------------new test-----------------------
# Input Sentence: به هنگام بشکوفهٔ گلستان بیاورد لشکر ز زابلستان
# Generated Sentence: به هنگام بشکوفهٔ گلستان بیاورد لشکر ز زابلستان
# Target Sentence: ز زال آگهی یافت افراسیاب برآمد ز آرام و از خورد و خواب
# -------------------------new test-----------------------
# Input Sentence: بنالید و برزد یکی باد سرد پس آنگه یکی سخت سوگند خورد
# Generated Sentence: بنالید و برزد یکی باد سرد پس آنگه یکی سخت سوگند خورد
# Target Sentence: بیزدان که بیزارم از تخت و گاه اگر نیز بیند سر من کلاه
# -------------------------new test-----------------------
# Input Sentence: وگرتان سوی شهر ایران هواست دل هر کسی بر تنش پادشاست
# Generated Sentence: وگرتان سوی شهر ایران هواست دل هر کسی بر تنش پادشاست
# Target Sentence: ز ما دو برادر مدارید چشم که هرگز نشوییم دل را ز خشم
# -------------------------new test-----------------------
# Input Sentence: بفرمود تا رفت پیشش دبیر نوشتن یکی نامه ای بر حریر
# Generated Sentence: بفرمود تا رفت پیشش دبیر نوشتن یکی نامه ای بر حریر
# Target Sentence: نخست آفرین کرد بر دادگر کزو دید نیروی و فر و هنر
# -------------------------new test-----------------------
# Input Sentence: چو بنشست بر تخت و گاه پدر جهان را همی داشت با زیب و فر
# Generated Sentence: چو بنشست بر تخت و گاه پدر جهان را همی داشت با زیب و فر
# Target Sentence: چنین تا برآمد برین روزگار درخت بلا کینه آورد بار
# -------------------------new test-----------------------
# Input Sentence: چنین بود تا بود دور زمان بنوی تو اندر شگفتی ممان
# Generated Sentence: چنین بود تا بود دور زمان بنوی تو اندر شگفتی ممان
# Target Sentence: یکی را همه بهره شهدست و قند تن آسانی و ناز و بخت بلند
# -------------------------new test-----------------------
# Input Sentence: همی یاد کردند رزم فرود پشیمانی و درد و تیمار بود
# Generated Sentence: همی یاد کردند رزم فرود پشیمانی و درد و تیمار بود
# Target Sentence: همه دل پر از درد و از بیم شاه دو دیده پر از خون و تن پر گناه
# -------------------------new test-----------------------
# Input Sentence: بدو داد با تیغ و بر گستوان همان نیزه و درع و خود گوان
# Generated Sentence: بدو داد با تیغ و بر گستوان همان نیزه و درع و خود گوان
# Target Sentence: بیاراست آن جنگ را پیلسم همی راند چون شیر با باد و دم
# -------------------------new test-----------------------
# Input Sentence: سپهدار پیران غمی گشت سخت برآشفت با تیره خورشید بخت
# Generated Sentence: سپهدار پیران غمی گشت سخت برآشفت با تیره خورشید بخت
# Target Sentence: ازان پس نگه کرد جای سپاه نیامدش بر آرزو رزمگاه
# -------------------------new test-----------------------
# Input Sentence: دو چشم کیانی به هم بر نهاد بپژمرد و برزد یکی سرد باد
# Generated Sentence: دو چشم کیانی به هم بر نهاد بپژمرد و برزد یکی سرد باد
# Target Sentence: شد آن نامور پرهنر شهریار به گیتی سخن ماند زو یادگار
# -------------------------new test-----------------------
# Input Sentence: درودست باری که بس ناگهان رسیدی به نزدیک شاه جهان
# Generated Sentence: درودست باری که بس ناگهان رسیدی به نزدیک شاه جهان
# Target Sentence: بفرمود تا پرده برداشتند باسبش ز درگاه بگذاشتند
# -------------------------new test-----------------------
# Input Sentence: وگر در میان دو رویه سپاه بگردی بلاف از پی نام و جاه
# Generated Sentence: وگر در میان دو رویه سپاه بگردی بلاف از پی نام و جاه
# Target Sentence: کجا دشمن و دوست بیند ترا دل اکنون کجا برگزیند ترا
# -------------------------new test-----------------------
# Input Sentence: چو خورشید تابان برآمد ز کوه برفتند گردان همه همگروه
# Generated Sentence: چو خورشید تابان برآمد ز کوه برفتند گردان همه همگروه
# Target Sentence: بدیدند مر پهلوان را پگاه وزان جایگه برگرفتند راه
# -------------------------new test-----------------------
# Input Sentence: جز از آشتی جستنت رای نیست که با او سپاه ترا پای نیست
# Generated Sentence: جز از آشتی جستنت رای نیست که با او سپاه ترا پای نیست
# Target Sentence: زمینی کجا آفریدون گرد بدانگه به تور دلاور سپرد
# -------------------------new test-----------------------
# Input Sentence: برفت از بر من سپیده دمان همان بیژنش کند سر در زمان
# Generated Sentence: برفت از بر من سپیده دمان همان بیژنش کند سر در زمان
# Target Sentence: من از درد دل برکشیدم سپاه غریوان برفتم به آوردگاه
# -------------------------new test-----------------------
# Input Sentence: بدل گفت خیره بیازردمش چرا خواسته پیش ناوردمش
# Generated Sentence: بدل گفت خیره بیازردمش چرا خواسته پیش ناوردمش
# Target Sentence: گر او را ز هومان بد آید بسر چه باید مرا درع و تیغ و کمر
# -------------------------new test-----------------------
# Input Sentence: جز از رای و فرمان او راه نیست خور و ماه ازین دانش آگاه نیست
# Generated Sentence: جز از رای و فرمان او راه نیست خور و ماه ازین دانش آگاه نیست
# Target Sentence: پسر را بفرمود گودرز پیر به توران شدن کار را ناگریز
# -------------------------new test-----------------------
# Input Sentence: بیازارد از من جهاندار شاه گر از یکدگر بگسلانم سپاه
# Generated Sentence: بیازارد از من جهاندار شاه گر از یکدگر بگسلانم سپاه
# Target Sentence: نهم آنک گفتی مبارز گزین که با من بگردد برین دشت کین
# -------------------------new test-----------------------
# Input Sentence: بر مسیره شیر جنگی طبرد بشد تیز با نامداران گرد
# Generated Sentence: بر مسیره شیر جنگی طبرد بشد تیز با نامداران گرد
# Target Sentence: چو کیخسرو آن رزم ترکان بدید که خورشید گشت از جهان ناپدید
# -------------------------new test-----------------------
# Input Sentence: همه بخردان و ردان سپاه بواز گفتند کین نیست راه
# Generated Sentence: همه بخردان و ردان سپاه بواز گفتند کین نیست راه
# Target Sentence: جهاندیده پردانش افراسیاب جز از چاره جستن نبیند بخواب
# -------------------------new test-----------------------
# Input Sentence: چنینست کین شاه گوید همی جز از نیک نامی نجوید همی
# Generated Sentence: چنینست کین شاه گوید همی جز از نیک نامی نجوید همی
# Target Sentence: ولیکن بدین رای هشیار من یکی بنگرد ژرف سالار من
# -------------------------new test-----------------------
# Input Sentence: پیاده صفی از پس نیزه دار سپردار با تیر جوشن گذار
# Generated Sentence: پیاده صفی از پس نیزه دار سپردار با تیر جوشن گذار
# Target Sentence: پس پشت ایشان سواران جنگ برآگنده ترکش ز تیر خدنگ
# -------------------------new test-----------------------
# Input Sentence: ز جنگ آوران لشکری برگزین بمن ده تو بنگر کنون رزم و کین
# Generated Sentence: ز جنگ آوران لشکری برگزین بمن ده تو بنگر کنون رزم و کین
# Target Sentence: چو بشنید پیران ز هومان سخن بدو گفت مشتاب و تندی مکن
# -------------------------new test-----------------------
# Input Sentence: سیاووش را تنگ در برگرفت ز کردار بد پوزش اندر گرفت
# Generated Sentence: سیاووش را تنگ در برگرفت ز کردار بد پوزش اندر گرفت
# Target Sentence: سیاوش به پیش جهاندار پاک بیامد بمالید رخ را به خاک
# -------------------------new test-----------------------
# Input Sentence: همان اسبش از تشنگی شد غمی بنیروی مرد اندر آمد کمی
# Generated Sentence: همان اسبش از تشنگی شد غمی بنیروی مرد اندر آمد کمی
# Target Sentence: چو درمانده شد با دل اندیشه کرد که گر شاه را گویم اندر نبرد
# -------------------------new test-----------------------
# Input Sentence: سواران جنگاوران سی هزار گزیده همه از در کارزار
# Generated Sentence: سواران جنگاوران سی هزار گزیده همه از در کارزار
# Target Sentence: چو گرسیوز از پشت لشکر برفت بپیش برادر خرامید تفت
# -------------------------new test-----------------------
# Input Sentence: بگفتم که چندین برین بر نهم همه نیکویها به دختر دهم
# Generated Sentence: بگفتم که چندین برین بر نهم همه نیکویها به دختر دهم
# Target Sentence: مرا گفت با خواسته کار نیست به دختر مرا راه دیدار نیست
# -------------------------new test-----------------------
# Input Sentence: سخن هر چه گویم همه گفته اند بر باغ دانش همه رفته اند
# Generated Sentence: سخن هر چه گویم همه گفته اند بر باغ دانش همه رفته اند
# Target Sentence: اگر بر درخت برومند جای نیابم که از بر شدن نیست رای
# -------------------------new test-----------------------
# Input Sentence: سیاوش سپر خواست گیلی چهار دو چوبین و دو ز آهن آبدار
# Generated Sentence: سیاوش سپر خواست گیلی چهار دو چوبین و دو ز آهن آبدار
# Target Sentence: کمان خواست با تیرهای خدنگ شش اندر میان زد سه چوبه به تنگ
# -------------------------new test-----------------------
# Input Sentence: چنین گفت خرم دل رهنمای که خوبی گزین زین سپنجی سرای
# Generated Sentence: چنین گفت خرم دل رهنمای که خوبی گزین زین سپنجی سرای
# Target Sentence: بنوش و بناز و بپوش و بخور ترا بهره اینست زین رهگذر
# -------------------------new test-----------------------
# Input Sentence: پس آگاهی آمد بر شهریار که آمد ز ره پهلوان سوار
# Generated Sentence: پس آگاهی آمد بر شهریار که آمد ز ره پهلوان سوار
# Target Sentence: زواره فرامرز و دستان سام بزرگان که هستند با جاه و نام
# -------------------------new test-----------------------
# Input Sentence: یکی کودکی دارم اندر نهان ز پشت تو ای شهریار جهان
# Generated Sentence: یکی کودکی دارم اندر نهان ز پشت تو ای شهریار جهان
# Target Sentence: ز بس رنج کشتنش نزدیک بود جهان پیش من تنگ و تاریک بود
# -------------------------new test-----------------------
# Input Sentence: همی کرد گودرز هر سو نگاه سپاه اندر آمد بگرد سپاه
# Generated Sentence: همی کرد گودرز هر سو نگاه سپاه اندر آمد بگرد سپاه
# Target Sentence: سراسیمه شد خفته از داروگیر برآمد یکی ابر بارانش تیر
# -------------------------new test-----------------------
# Input Sentence: به خارا و سغد و سمرقند و چاچ سپیجاب و آن کشور و تخت عاج
# Generated Sentence: به خارا و سغد و سمرقند و چاچ سپیجاب و آن کشور و تخت عاج
# Target Sentence: تهی کرد و شد با سپه سوی گنگ بهانه نجست و فریب و درنگ
# -------------------------new test-----------------------
# Input Sentence: بفرمودشان جنگ را ساختن دل و گوش دادن بکین آختن
# Generated Sentence: بفرمودشان جنگ را ساختن دل و گوش دادن بکین آختن
# Target Sentence: برفتند پیش سپهبد گروه بر انبوه لشکر بکردار کوه
# -------------------------new test-----------------------
# Input Sentence: نشاید که باشی تو اندر زمین جز آویختن نیست پاداش این
# Generated Sentence: نشاید که باشی تو اندر زمین جز آویختن نیست پاداش این
# Target Sentence: بدو گفت سودابه کای شهریار تو آتش بدین تارک من ببار
# -------------------------new test-----------------------
# Input Sentence: چو پیش پدر شد سیاووش پاک نه دود و نه آتش نه گرد و نه خاک
# Generated Sentence: چو پیش پدر شد سیاووش پاک نه دود و نه آتش نه گرد و نه خاک
# Target Sentence: فرود آمد از اسپ کاووس شاه پیاده سپهبد پیاده سپاه
# -------------------------new test-----------------------
# Input Sentence: بفرمود تا سنگهای گران کشیدند بر باره افسونگران
# Generated Sentence: بفرمود تا سنگهای گران کشیدند بر باره افسونگران
# Target Sentence: بس کاردانان رومی بخواند سپاهی بدیوار دژ برنشاند
# -------------------------new test-----------------------
# Input Sentence: ز بدخواه روز و شب اندیشه کرد شب روز را دل یکی پیشه کرد
# Generated Sentence: ز بدخواه روز و شب اندیشه کرد شب روز را دل یکی پیشه کرد
# Target Sentence: بیامد ز چین تا بب زره میان سوده از رنج و بند گره
# -------------------------new test-----------------------
# Input Sentence: برفتند تا خانهٔ زرنگار کجا اندرو بود خرم بهار
# Generated Sentence: برفتند تا خانهٔ زرنگار کجا اندرو بود خرم بهار
# Target Sentence: نگه کرد سام اندران ماه روی یکایک شگفتی بماند اندروی
# -------------------------new test-----------------------
# Input Sentence: ز تخم فریدون منم کیقباد پدر بر پدر نام دارم به یاد
# Generated Sentence: ز تخم فریدون منم کیقباد پدر بر پدر نام دارم به یاد
# Target Sentence: چو بشنید رستم فرو برد سر به خدمت فرود آمد از تخت زر
# -------------------------new test-----------------------
# Input Sentence: چو گیرد بلندی چه خواهد بدن همی داستان از چه خواهد زدن
# Generated Sentence: چو گیرد بلندی چه خواهد بدن همی داستان از چه خواهد زدن
# Target Sentence: ستاره شناسان هم اندر زمان از اختر گرفتند پیدا نشان
# -------------------------new test-----------------------
# Input Sentence: کسی کز نژاد سیاوش بود خردمند و بیدار و خامش بود
# Generated Sentence: کسی کز نژاد سیاوش بود خردمند و بیدار و خامش بود
# Target Sentence: بگفت ستاره شمر مگرو ایچ خردگیر و کار سیاوش بسیچ
# -------------------------new test-----------------------
# Input Sentence: چنان کرد رستم که خسرو بگفت ببردند پرده سرای از نهفت
# Generated Sentence: چنان کرد رستم که خسرو بگفت ببردند پرده سرای از نهفت
# Target Sentence: بهامون کشیدند ایرانیان بفرمان ببستند یکسر میان
# -------------------------new test-----------------------
# Input Sentence: یکی جنگ با بیژن افگند پی که این دشت رزم است گر باغ می
# Generated Sentence: یکی جنگ با بیژن افگند پی که این دشت رزم است گر باغ می
# Target Sentence: وزان پس بیامد سوی کارزار بره برشتابید چندی سوار
# -------------------------new test-----------------------
# Input Sentence: همه رزمگه سربسر ماتمست بدین کار فریادرس رستمست
# Generated Sentence: همه رزمگه سربسر ماتمست بدین کار فریادرس رستمست
# Target Sentence: ازان پس خروشیدن ناله خاست ز قلب و چپ لشکر و دست راست
# -------------------------new test-----------------------
# Input Sentence: بزد اسپ و راند از میان گروه پراندیشه بنهاد سر سوی کوه
# Generated Sentence: بزد اسپ و راند از میان گروه پراندیشه بنهاد سر سوی کوه
# Target Sentence: چنین گفت پس نامور با تخوار که این کیست کامد چنین خوارخوار
# -------------------------new test-----------------------
# Input Sentence: ز چین و ختن هدیه ها ساختند بدان کار گنجی بپرداختند
# Generated Sentence: ز چین و ختن هدیه ها ساختند بدان کار گنجی بپرداختند
# Target Sentence: فرستاده ای نیک دل را بخواند سخنهای شایسته چندی براند
# -------------------------new test-----------------------
# Input Sentence: کنون از پس کوه چون مستمند نشستی بکردار غرم نژند
# Generated Sentence: کنون از پس کوه چون مستمند نشستی بکردار غرم نژند
# Target Sentence: بکردار نخچیر کز شرزه شیر گریزان و شیر از پس اندر دلیر
# -------------------------new test-----------------------
# Input Sentence: نگارندهٔ چرخ گردنده اوست فرایندهٔ فره بنده اوست
# Generated Sentence: نگارندهٔ چرخ گردنده اوست فرایندهٔ فره بنده اوست
# Target Sentence: چو دریا و کوه و زمین آفرید بلند آسمان از برش برکشید
# -------------------------new test-----------------------
# Input Sentence: بدین گنج بادآور آباد کن درم خوار کن مرگ را یاد کن
# Generated Sentence: بدین گنج بادآور آباد کن درم خوار کن مرگ را یاد کن
# Target Sentence: دگر گنج کش خواندندی عروس که آگند کاوس در شهر طوس
# -------------------------new test-----------------------
# Input Sentence: ز هرای اسپان و آوای کوس همی آسمان بر زمین داد بوس
# Generated Sentence: ز هرای اسپان و آوای کوس همی آسمان بر زمین داد بوس
# Target Sentence: سپهدار هومان دمان پیش صف یکی خشت رخشان گرفته بکف
# -------------------------new test-----------------------
# Input Sentence: سیه گشت رخشنده روز سپید گسستند پیوند از جمشید
# Generated Sentence: سیه گشت رخشنده روز سپید گسستند پیوند از جمشید
# Target Sentence: برو تیره شد فرهٔ ایزدی به کژی گرایید و نابخردی
# -------------------------new test-----------------------
# Input Sentence: چنین گفت ازان پس بمادر فرود کز ایران سخن با که باید سرود
# Generated Sentence: چنین گفت ازان پس بمادر فرود کز ایران سخن با که باید سرود
# Target Sentence: که باید که باشد مرا پایمرد ازین سرفرازان روز نبرد
# -------------------------new test-----------------------
# Input Sentence: فرود آمد از باره جنگی پلنگ دو دست از پس پشت بستش چو سنگ
# Generated Sentence: فرود آمد از باره جنگی پلنگ دو دست از پس پشت بستش چو سنگ
# Target Sentence: نشست از بر زین و او را بپیش دوانید و شد تا بر یار خویش
# -------------------------new test-----------------------
# Input Sentence: بشیده چنین گفت کای پر خرد سپاه تو تیمار تو کی خورد
# Generated Sentence: بشیده چنین گفت کای پر خرد سپاه تو تیمار تو کی خورد
# Target Sentence: چنین دان که این لشکر بی شمار که آمد برین مرز چندین هزار
# -------------------------new test-----------------------
# Input Sentence: یکی تیغ زد زود بر گردنش بدو نیمه شد خسروانی تنش
# Generated Sentence: یکی تیغ زد زود بر گردنش بدو نیمه شد خسروانی تنش
# Target Sentence: بفرمود تا سرش برداشتند به نیزه به ابر اندر افراشتند
# -------------------------new test-----------------------
# Input Sentence: بدو گفت پولادوند ای دلیر جهاندیده و نامبردار و شیر
# Generated Sentence: بدو گفت پولادوند ای دلیر جهاندیده و نامبردار و شیر
# Target Sentence: که بگریزد از پیش تو ژنده پیل ببینی کنون موج دریای نیل
# -------------------------new test-----------------------
# Input Sentence: شهنشاه ایران زبان برگشاد و زآن تشت و خنجر بسی کرد یاد
# Generated Sentence: شهنشاه ایران زبان برگشاد و زآن تشت و خنجر بسی کرد یاد
# Target Sentence: ز تور و فریدون و سلم سترگ ز ایرج که بد پادشاه بزرگ
# -------------------------new test-----------------------
# Input Sentence: زمین را همی دل برآمد ز جای ز بس نالهٔ بوق و شیپور و نای
# Generated Sentence: زمین را همی دل برآمد ز جای ز بس نالهٔ بوق و شیپور و نای
# Target Sentence: چو خورشید برداشت از چرخ زنگ بدرید پیراهن مشک رنگ
# -------------------------new test-----------------------
# Input Sentence: اگر کشته بودند اگر خسته تن گرفتار در دست آن انجمن
# Generated Sentence: اگر کشته بودند اگر خسته تن گرفتار در دست آن انجمن
# Target Sentence: ز پرمایه اسپان زرین ستام ز ترگ و ز شمشیر زرین نیام
# -------------------------new test-----------------------
# Input Sentence: برآرد گل تازه از خار خشک شود خاک بابخت بیدار مشک
# Generated Sentence: برآرد گل تازه از خار خشک شود خاک بابخت بیدار مشک
# Target Sentence: شگفتی تر آنک از پی آز مرد همیشه دل خویش دارد بدرد
# -------------------------new test-----------------------
# Input Sentence: بسودم بهر جای بابخت جنگ گهٔ نام جستن نمردم بننگ
# Generated Sentence: بسودم بهر جای بابخت جنگ گهٔ نام جستن نمردم بننگ
# Target Sentence: ببیژن نمود آنگهی هر دو تور که بودند کشته فگنده بدور
# -------------------------new test-----------------------
# Input Sentence: همی گفت رستم که ای مهتران جهان دیده و رنجبرده سران
# Generated Sentence: همی گفت رستم که ای مهتران جهان دیده و رنجبرده سران
# Target Sentence: نباید که این رنج بی بر شود به ناز و تن آسانی اندر شود
# -------------------------new test-----------------------
# Input Sentence: به هشتم نشستند بر زین همه جهانجوی و گردنکشان و رمه
# Generated Sentence: به هشتم نشستند بر زین همه جهانجوی و گردنکشان و رمه
# Target Sentence: همه برکشیدند گرز گران پراگنده در شهر مازندران
# -------------------------new test-----------------------
# Input Sentence: چو بشنید گیو این سخن بردمید بزد دست و تیغ از میان برکشید
# Generated Sentence: چو بشنید گیو این سخن بردمید بزد دست و تیغ از میان برکشید
# Target Sentence: بدو گفت رستم به یک ترک جنگ نسازد همانا که آیدش ننگ
# -------------------------new test-----------------------
# Input Sentence: بمن بخش گرگین میلاد را ز دل دور کن کین و بیداد را
# Generated Sentence: بمن بخش گرگین میلاد را ز دل دور کن کین و بیداد را
# Target Sentence: بدو گفت بیژن که ای یار من ندانی که چون بود پیکار من
# -------------------------new test-----------------------
# Input Sentence: شگفتی همی بینم از تو یکی وگر چند هستم بهوش اندکی
# Generated Sentence: شگفتی همی بینم از تو یکی وگر چند هستم بهوش اندکی
# Target Sentence: کزین رزمگه بوستان ساختی دل از کین ترکان بپرداختی
# -------------------------new test-----------------------
# Input Sentence: نشستند با آرامش و رود و می یکی دست رود و دگر دست نی
# Generated Sentence: نشستند با آرامش و رود و می یکی دست رود و دگر دست نی
# Target Sentence: برفتند هر کس برام خویش گرفته ببر هر کسی کام خویش
# -------------------------new test-----------------------
# Input Sentence: گرامیش دارید و نوشه خورید چو پرورده شد تن روان پرورید
# Generated Sentence: گرامیش دارید و نوشه خورید چو پرورده شد تن روان پرورید
# Target Sentence: چو از بودنش بگذرد روز چند فرستید با زی منش ارجمند
# -------------------------new test-----------------------
# Input Sentence: جهانجوی را دل بجنگ اندرست وگرنه سرش زیر سنگ اندرست
# Generated Sentence: جهانجوی را دل بجنگ اندرست وگرنه سرش زیر سنگ اندرست
# Target Sentence: دلیری کجا نام او اشکبوس همی بر خروشید بر سان کوس
# -------------------------new test-----------------------
# Input Sentence: که اکنون تو بازآمدی تندرست بب مژه رخ نبایست شست
# Generated Sentence: که اکنون تو بازآمدی تندرست بب مژه رخ نبایست شست
# Target Sentence: بپیچید زان کار پرمایه گیو که آمد پیاده سپهدار نیو
# -------------------------new test-----------------------
# Input Sentence: بسالار بهرام گودرز گفت که این کار بر من نشاید نهفت
# Generated Sentence: بسالار بهرام گودرز گفت که این کار بر من نشاید نهفت
# Target Sentence: روم هرچ گفتی بجای آورم سر کوه یکسر بپای آورم
# -------------------------new test-----------------------
# Input Sentence: چو بگشاد آن گنج آباد را وصی کرد گودرز کشواد را
# Generated Sentence: چو بگشاد آن گنج آباد را وصی کرد گودرز کشواد را
# Target Sentence: بدو گفت بنگر بکار جهان چه در آشکار و چه اندر نهان
# -------------------------new test-----------------------
# Input Sentence: سوی من فرستش هم اکنون دمان ببینیم تا بر چه گردد زمان
# Generated Sentence: سوی من فرستش هم اکنون دمان ببینیم تا بر چه گردد زمان
# Target Sentence: بدو گفت هومان که ای سرفراز بدیدار پیرانت آمد نیاز
# -------------------------new test-----------------------
# Input Sentence: بران ترگ زرین و زرین سپر غمی شد سر از چاک چاک تبر
# Generated Sentence: بران ترگ زرین و زرین سپر غمی شد سر از چاک چاک تبر
# Target Sentence: تو گفتی که ابری برآمد ز کنج ز شنگرف نیرنگ زد بر ترنج
# -------------------------new test-----------------------
# Input Sentence: سوی شهر ایران نهادند روی فرنگیس و شاه و گو جنگ جوی
# Generated Sentence: سوی شهر ایران نهادند روی فرنگیس و شاه و گو جنگ جوی
# Target Sentence: چو بشنید پیران غمی گشت سخت بلرزید برسان برگ درخت
# -------------------------new test-----------------------
# Input Sentence: بهومان چنین گفت کای بادسار ببردی ز من دوش سر یاددار
# Generated Sentence: بهومان چنین گفت کای بادسار ببردی ز من دوش سر یاددار
# Target Sentence: امیدستم امروز کین تیغ من سرت را ز بن بگسلاند ز تن
# -------------------------new test-----------------------
# Input Sentence: همه بر نهادند سر بر زمین پر از خون دل و دیده پر آب کین
# Generated Sentence: همه بر نهادند سر بر زمین پر از خون دل و دیده پر آب کین
# Target Sentence: سپهبد سوی آسمان کرد سر که ای دادگر داور چاره گر
# -------------------------new test-----------------------
# Input Sentence: مه فرودین وسر سال بود لب رود لشکرگه زال بود
# Generated Sentence: مه فرودین وسر سال بود لب رود لشکرگه زال بود
# Target Sentence: همی گل چدند از لب رودبار رخان چون گلستان و گل در کنار
# -------------------------new test-----------------------
# Input Sentence: یکی چاره باید کنون اندرین که این بد بگردد ز ایران زمین
# Generated Sentence: یکی چاره باید کنون اندرین که این بد بگردد ز ایران زمین
# Target Sentence: چنین گفت پس طوس با مهتران که ای رزم دیده دلاور سران
# -------------------------new test-----------------------
# Input Sentence: بایران نبرده بتیر و کمان نبد چون فروهل دگر بدگمان
# Generated Sentence: بایران نبرده بتیر و کمان نبد چون فروهل دگر بدگمان
# Target Sentence: چو از دور ترک دژم را بدید کمان را بزه کرد و اندر کشید
# -------------------------new test-----------------------
# Input Sentence: مرا با تو امروز پیمان یکیست بگوییم و گفتار ما اندکیست
# Generated Sentence: مرا با تو امروز پیمان یکیست بگوییم و گفتار ما اندکیست
# Target Sentence: اگر پهلوان را نمایی به من سرافراز باشی به هر انجمن
# -------------------------new test-----------------------
# Input Sentence: بروشن روان سیاوش که مرگ مرا خوشتر از جوشن و تیغ و ترگ
# Generated Sentence: بروشن روان سیاوش که مرگ مرا خوشتر از جوشن و تیغ و ترگ
# Target Sentence: گر ایدونکه جنگی بود هم گروه تلی کشته بینی ببالای کوه
# -------------------------new test-----------------------
# Input Sentence: سپه را ز کار بدی باز داشت که با پاک یزدان یکی راز داشت
# Generated Sentence: سپه را ز کار بدی باز داشت که با پاک یزدان یکی راز داشت
# Target Sentence: گرفتن نیارست و بستن کسی وزان پس ندیدند کشتن بسی
# -------------------------new test-----------------------
# Input Sentence: هر آنگه که بیگانه شد خویش تو بدانست راز کم و بیش تو
# Generated Sentence: هر آنگه که بیگانه شد خویش تو بدانست راز کم و بیش تو
# Target Sentence: چو جویی دگر زو تو بیگانگی کند رهنمونی به دیوانگی
# -------------------------new test-----------------------
# Input Sentence: همان مادرش را که از تخت و گاه ز پرده کشیدند یکسو براه
# Generated Sentence: همان مادرش را که از تخت و گاه ز پرده کشیدند یکسو براه
# Target Sentence: شبان پروریدست وز گوسفند مزیدست شیر این شه هوشمند
# -------------------------new test-----------------------
# Input Sentence: بزد دست و بگسست زنجیر و بند رها کرد ازو حلقهٔ پای بند
# Generated Sentence: بزد دست و بگسست زنجیر و بند رها کرد ازو حلقهٔ پای بند
# Target Sentence: سوی خانه رفتند زان چاهسار بیک دست بیژن بدیگر زوار
# -------------------------new test-----------------------
# Input Sentence: درفشی فرستاد و سیصد سوار نگهبان لشکر سوی رودبار
# Generated Sentence: درفشی فرستاد و سیصد سوار نگهبان لشکر سوی رودبار
# Target Sentence: همیدون فرستاد بر سوی کوه درفشی و سیصد ز گردان گروه
# -------------------------new test-----------------------
# Input Sentence: صفی برکشیدند پیش سوار سپردار و ژوپین ور و نیزه دار
# Generated Sentence: صفی برکشیدند پیش سوار سپردار و ژوپین ور و نیزه دار
# Target Sentence: مجنبید گفت ایچ از جای خویش سپر با سنان اندرارید پیش
# -------------------------new test-----------------------
# Input Sentence: وزو نیوتر آرش رزم زن بهر کار پیروز و لشکر شکن
# Generated Sentence: وزو نیوتر آرش رزم زن بهر کار پیروز و لشکر شکن
# Target Sentence: یکی آنک بر کشوری شاه بود گه رزم با بخت همراه بود
# -------------------------new test-----------------------
# Input Sentence: برو آفرین کرد شاه جهان که بیشی ترا باد و فر مهان
# Generated Sentence: برو آفرین کرد شاه جهان که بیشی ترا باد و فر مهان
# Target Sentence: بهر کار بخت تو پیروز باد بباز آمدن باد پیروز و شاد
# -------------------------new test-----------------------
# Input Sentence: نشاید جز از من که سازم نبرد بدان تا برآرم ز مردیش گرد
# Generated Sentence: نشاید جز از من که سازم نبرد بدان تا برآرم ز مردیش گرد
# Target Sentence: بدو گفت گیو ای پسر هوش دار بگفتار من سربسر گوش دار
# -------------------------new test-----------------------
# Input Sentence: تبیره برآمد ز پرده سرای خروشیدن زنگ و هندی داری
# Generated Sentence: تبیره برآمد ز پرده سرای خروشیدن زنگ و هندی داری
# Target Sentence: بدین سان سپاهی بیامد ز گنگ که خورشید را آرزو کرد جنگ
# -------------------------new test-----------------------
# Input Sentence: ترا گفت ز ایدر بباید شدن بر او فراوان نباید بدن
# Generated Sentence: ترا گفت ز ایدر بباید شدن بر او فراوان نباید بدن
# Target Sentence: بپرسی و گویی کزان جشن گاه نخواهی همی کرد کس را نگاه
# -------------------------new test-----------------------
# Input Sentence: بیامد ازان کینه چون پیل مست مران گاو برمایه را کرد پست
# Generated Sentence: بیامد ازان کینه چون پیل مست مران گاو برمایه را کرد پست
# Target Sentence: همه هر چه دید اندرو چارپای بیفگند و زیشان بپرداخت جای
# -------------------------new test-----------------------
# Input Sentence: کجات آن بزرگی و تخت و کلاه کجات آن بروبوم و چندان سپاه
# Generated Sentence: کجات آن بزرگی و تخت و کلاه کجات آن بروبوم و چندان سپاه
# Target Sentence: که اکنون بدین تنگ غار اندری گریزان بسنگین حصار اندری
# -------------------------new test-----------------------
# Input Sentence: برانگیخت از شهر ایران ترا که بر مهر دید از دلیران ترا
# Generated Sentence: برانگیخت از شهر ایران ترا که بر مهر دید از دلیران ترا
# Target Sentence: به بخت تو آرام گیرد جهان شود جنگ و ناخوبی اندر نهان
# -------------------------new test-----------------------
# Input Sentence: سپاهی بسوی بیابان سترگ فرستاد سالار ایشان طورگ
# Generated Sentence: سپاهی بسوی بیابان سترگ فرستاد سالار ایشان طورگ
# Target Sentence: پذیرفت زین هر یکی جنگ شاه که بر نامداران ببندند راه
# -------------------------new test-----------------------
# Input Sentence: نگهبان در گفت کامروز کار نباید گرفتن بدان هم شمار
# Generated Sentence: نگهبان در گفت کامروز کار نباید گرفتن بدان هم شمار
# Target Sentence: که زال سپهبد بکابل نبود سراپردهٔ شاه زابل نبود
# -------------------------new test-----------------------
# Input Sentence: همان روز کیخسرو آنجا رسید زمین کوه تا کوه لشکر کشید
# Generated Sentence: همان روز کیخسرو آنجا رسید زمین کوه تا کوه لشکر کشید
# Target Sentence: بزنهار شد لشکر ما همه هراسان شد از بی شبانی رمه
# -------------------------new test-----------------------
# Input Sentence: بنیکی رساند دل دوستان گزند آید از وی بناراستان
# Generated Sentence: بنیکی رساند دل دوستان گزند آید از وی بناراستان
# Target Sentence: چو لهراسپ بنشست بر تخت داد به شاهنشهی تاج بر سر نهاد
# -------------------------new test-----------------------
# Input Sentence: درفشی درفشان پس پشت اوی یکی زابلی تیغ در مشت اوی
# Generated Sentence: درفشی درفشان پس پشت اوی یکی زابلی تیغ در مشت اوی
# Target Sentence: غو دیده بشنید دستان سام بفرمود بر چرمه کردن لگام
# -------------------------new test-----------------------
# Input Sentence: مهان پیش او خاک دادند بوس ز درگاه برخاست آوای کوس
# Generated Sentence: مهان پیش او خاک دادند بوس ز درگاه برخاست آوای کوس
# Target Sentence: دمادم برون رفت لشکر ز شهر وزان شهر نایافته هیچ بهر
# -------------------------new test-----------------------
# Input Sentence: گر ایدونک از چنگ این اژدها بریده پی و پوست یابم رها
# Generated Sentence: گر ایدونک از چنگ این اژدها بریده پی و پوست یابم رها
# Target Sentence: نه کهتر نه برتر منش مهتران نبینند نیزم به مازندران
# -------------------------new test-----------------------
# Input Sentence: زمین را ببوسید و بردش نماز بتابید سر سوی راه دراز
# Generated Sentence: زمین را ببوسید و بردش نماز بتابید سر سوی راه دراز
# Target Sentence: بسی آفرین خواند بر شاه نو که هر دم فزون باش چون ماه نو
# -------------------------new test-----------------------
# Input Sentence: ورا پیلتن گفت کین غم مدار به کام تو گردد همه روزگار
# Generated Sentence: ورا پیلتن گفت کین غم مدار به کام تو گردد همه روزگار
# Target Sentence: وزان روی منزل بمنزل سپاه همی رفت و پیش اندر آمد دو راه
# -------------------------new test-----------------------
# Input Sentence: همی تاخت تا قلب توران سپاه بینداختش خوار در قلبگاه
# Generated Sentence: همی تاخت تا قلب توران سپاه بینداختش خوار در قلبگاه
# Target Sentence: چنین گفت کاین را به دیبای زرد بپوشید کز گرد شد لاژورد
# -------------------------new test-----------------------
# Input Sentence: ببخشود و گفتش که ای خوب چهر که یزدان ترا زو مبراد مهر
# Generated Sentence: ببخشود و گفتش که ای خوب چهر که یزدان ترا زو مبراد مهر
# Target Sentence: بگویش که آری خداوند رخش ترا داد یزدان فریاد بخش
# -------------------------new test-----------------------
# Input Sentence: همان رای زد با تهمتن بران چنین تا رخ روز شد در نهان
# Generated Sentence: همان رای زد با تهمتن بران چنین تا رخ روز شد در نهان
# Target Sentence: چو خورشید بر زد سنان از نشیب شتاب آمد از رفتن با نهیب
# -------------------------new test-----------------------
# Input Sentence: اگر نیم ازین پیکر آید تنش سرش ابر ساید زمین دامنش
# Generated Sentence: اگر نیم ازین پیکر آید تنش سرش ابر ساید زمین دامنش
# Target Sentence: وزان پس فرستاده را پیش خواست درم ریخت تا بر سرش گشت راست
# -------------------------new test-----------------------
# Input Sentence: چنین داد پاسخ که ای پهلوان گر ایدون که بینی به روشن روان
# Generated Sentence: چنین داد پاسخ که ای پهلوان گر ایدون که بینی به روشن روان
# Target Sentence: سپه رانی و ما به کابل شویم بگوییم زین در سخن بشنویم
# -------------------------new test-----------------------
# Input Sentence: تهمتن بیامد سر و تن بشست بپیش جهانداور آمد نخست
# Generated Sentence: تهمتن بیامد سر و تن بشست بپیش جهانداور آمد نخست
# Target Sentence: ز پیروز گشتن نیایش گرفت جهان آفرین را ستایش گرفت
# -------------------------new test-----------------------
# Input Sentence: بدشنام بگشاد لب شهریار بران انجمن طوس را کرد خوار
# Generated Sentence: بدشنام بگشاد لب شهریار بران انجمن طوس را کرد خوار
# Target Sentence: ازان پس بدو گفت کای بدنشان که کمباد نامت ز گردنکشان
# -------------------------new test-----------------------
# Input Sentence: درفش خجسته برآورد راست شده شادمان یافته هرچ خواست
# Generated Sentence: درفش خجسته برآورد راست شده شادمان یافته هرچ خواست
# Target Sentence: خروشید زان پس که پیروز باد سر خسروان شاه فرخ نژاد
# -------------------------new test-----------------------
# Input Sentence: همانا بداندیش افراسیاب گذشتست زان سو بدریای آب
# Generated Sentence: همانا بداندیش افراسیاب گذشتست زان سو بدریای آب
# Target Sentence: چنان پیر بر گاه کاوس شاه نه اورنگ و فر و نه گنج و سپاه
# -------------------------new test-----------------------
# Input Sentence: بخواهد همی هرچ باید ز شاه بهر کار باشد زبان سپاه
# Generated Sentence: بخواهد همی هرچ باید ز شاه بهر کار باشد زبان سپاه
# Target Sentence: به سو طلایه پدیدار کرد سر خفته از خواب بیدار کرد
# -------------------------new test-----------------------
# Input Sentence: ببگماز بنشست یک روز شاد ز گردان لشکر همی کرد یاد
# Generated Sentence: ببگماز بنشست یک روز شاد ز گردان لشکر همی کرد یاد
# Target Sentence: بدیبا بیاراسته گاه شاه نهاده بسر بر کیانی کلاه
# -------------------------new test-----------------------
# Input Sentence: بجز بر تو بر کس ندیدمش مهر فراوان سخن گفت و نگشاد چهر
# Generated Sentence: بجز بر تو بر کس ندیدمش مهر فراوان سخن گفت و نگشاد چهر
# Target Sentence: ازین لشکر اکنون ترا خواستست ندانم که بر دل چه آراستست
# -------------------------new test-----------------------
# Input Sentence: کز ایدر بایوان خرامید زود مدارید در دل مرا جز درود
# Generated Sentence: کز ایدر بایوان خرامید زود مدارید در دل مرا جز درود
# Target Sentence: مباشید گستاخ با این جهان که او بتری دارد اندر نهان
# -------------------------new test-----------------------
# Input Sentence: چو خواهی که تاج تو ماند بجای مبادی جز آهسته و پاک رای
# Generated Sentence: چو خواهی که تاج تو ماند بجای مبادی جز آهسته و پاک رای
# Target Sentence: نگه کن که خود تاج با سر چه گفت که با مغزت ای سر خرد باد جفت
# -------------------------new test-----------------------
# Input Sentence: تو فرزند باشی و من چون پدر پدر پیش فرزند بسته کمر
# Generated Sentence: تو فرزند باشی و من چون پدر پدر پیش فرزند بسته کمر
# Target Sentence: چنان دان که کاووس بر تو به مهر بران گونه یک روز نگشاد چهر
# -------------------------new test-----------------------
# Input Sentence: سپهبد کزان گونه آوا شنید نگه کرد و خورشید رخ را بدید
# Generated Sentence: سپهبد کزان گونه آوا شنید نگه کرد و خورشید رخ را بدید
# Target Sentence: شده بام از آن گوهر تابناک به جای گل سرخ یاقوت خاک
# -------------------------new test-----------------------
# Input Sentence: بدو گفت شاها انوشه بدی روانرا بدیدار توشه بدی
# Generated Sentence: بدو گفت شاها انوشه بدی روانرا بدیدار توشه بدی
# Target Sentence: بریدی یکی راه دشوار و دور خریدی چنین رنج ما را بسور
# -------------------------new test-----------------------
# Input Sentence: چو بهرام و چون زنگهٔ شادروان چو فرهاد و برزین جنگ آوران
# Generated Sentence: چو بهرام و چون زنگهٔ شادروان چو فرهاد و برزین جنگ آوران
# Target Sentence: چنین لشکری سرفرازان جنگ همه نیزه و تیغ هندی به چنگ
# -------------------------new test-----------------------
# Input Sentence: برادر دو بودش دو فرخ همال ازو هر دو آزاده مهتر به سال
# Generated Sentence: برادر دو بودش دو فرخ همال ازو هر دو آزاده مهتر به سال
# Target Sentence: یکی بود ازیشان کیانوش نام دگر نام پرمایهٔ شادکام
# -------------------------new test-----------------------
# Input Sentence: شمردم همه باد گفتار شاه چنین هم همی گفت با من پگاه
# Generated Sentence: شمردم همه باد گفتار شاه چنین هم همی گفت با من پگاه
# Target Sentence: وزان پس چنین گفت با دل به مهر که از جنبش و راز گردان سپهر
# -------------------------new test-----------------------
# Input Sentence: بدو گفت رستم که شد تیره روز چه پیدا کند تیغ گیتی فروز
# Generated Sentence: بدو گفت رستم که شد تیره روز چه پیدا کند تیغ گیتی فروز
# Target Sentence: برین دشت هم دار و هم منبرست که روشن جهان زیر تیغ اندرست
# -------------------------new test-----------------------
# Input Sentence: تبیره برآمد ز هر جای و نای چو شاه جهان اندر آمد ز جای
# Generated Sentence: تبیره برآمد ز هر جای و نای چو شاه جهان اندر آمد ز جای
# Target Sentence: همه روی پیل از کران تا کران پر از مشک بود و می و زعفران
# -------------------------new test-----------------------
# Input Sentence: همی کرد پوزش ز بهر گناه مر او را همی جست هر سو سپاه
# Generated Sentence: همی کرد پوزش ز بهر گناه مر او را همی جست هر سو سپاه
# Target Sentence: خبر یافت زو رستم و گیو و طوس برفتند با لشکری گشن و کوس
# -------------------------new test-----------------------
# Input Sentence: دو فرزند بودش به کردار ماه سزاوار شاهی و تخت و کلاه
# Generated Sentence: دو فرزند بودش به کردار ماه سزاوار شاهی و تخت و کلاه
# Target Sentence: یکی نام گشتاسپ و دیگر زریر که زیر آوریدی سر نره شیر
# -------------------------new test-----------------------
# Input Sentence: یکی ناسگالیده شان جنگ خاست که از خون زمین گشت با کوه راست
# Generated Sentence: یکی ناسگالیده شان جنگ خاست که از خون زمین گشت با کوه راست
# Target Sentence: بکشتند ایرانیان هشت مرد دلیران و شیران روز نبرد
# -------------------------new test-----------------------
# Input Sentence: چو دانست گودرز کآمد سپاه بزد کوس و آمد ز زیبد براه
# Generated Sentence: چو دانست گودرز کآمد سپاه بزد کوس و آمد ز زیبد براه
# Target Sentence: ز کوه اندر آمد بهامون گذشت کشیدند لشکر بران پهن دشت
# -------------------------new test-----------------------
# Input Sentence: چو ضحاکش آورد ناگه به چنگ یکایک ندادش زمانی درنگ
# Generated Sentence: چو ضحاکش آورد ناگه به چنگ یکایک ندادش زمانی درنگ
# Target Sentence: به ارش سراسر به دو نیم کرد جهان را ازو پاک بی بیم کرد
# -------------------------new test-----------------------
# Input Sentence: که آزرده گشتست بر تو پدر یکی پوزش آور مکش هیچ سر
# Generated Sentence: که آزرده گشتست بر تو پدر یکی پوزش آور مکش هیچ سر
# ...
# -------------------------new test-----------------------
# Input Sentence: برستم ببخشید پیروز شاه رهانیدش از بند و تاریک چاه
# Generated Sentence: برستم ببخشید پیروز شاه رهانیدش از بند و تاریک چاه
# Target Sentence: ز رستم بپرسید پس شهریار که چون راند خواهی برین گونه کار
# -------------------------new test-----------------------
# Input Sentence: به هومان چنین گفت سهراب گرد که اندیشه از دل بباید سترد
# Generated Sentence: به هومان چنین گفت سهراب گرد که اندیشه از دل بباید سترد
# Target Sentence: نبینی تو زین لشکر بیکران یکی مرد جنگی و گرزی گران
# -------------------------new test-----------------------
# Input Sentence: همیدون سه چوبه بر اسب سوار بزد گیو پیکان آهن گذار
# Generated Sentence: همیدون سه چوبه بر اسب سوار بزد گیو پیکان آهن گذار
# Target Sentence: نشد اسب خسته نه پیران نیو بدانجا رسیدند یاران گیو
# -------------------------new test-----------------------
# Input Sentence: رسیدند پس پهلوانان بدوی نکوهش گر و تیز و پرخاشجوی
# Generated Sentence: رسیدند پس پهلوانان بدوی نکوهش گر و تیز و پرخاشجوی
# Target Sentence: بدو گفت گودرز بیمارستان ترا جای زیباتر از شارستان
# -------------------------new test-----------------------
# Input Sentence: ز هر گوشت از مرغ و از چارپای خورشگر بیاورد یک یک به جای
# Generated Sentence: ز هر گوشت از مرغ و از چارپای خورشگر بیاورد یک یک به جای
# Target Sentence: به خویش بپرورد برسان شیر بدان تا کند پادشا را دلیر
# -------------------------new test-----------------------
# Input Sentence: یکی رخش را تیز بنمود ران تگ گور شد از تگ او گران
# Generated Sentence: یکی رخش را تیز بنمود ران تگ گور شد از تگ او گران
# Target Sentence: کمند و پی رخش و رستم سوار نیابد ازو دام و دد زینهار
# -------------------------new test-----------------------
# Input Sentence: بشد ترجمان بیژن آمد دمان بکوه کنابد بزه بر کمان
# Generated Sentence: بشد ترجمان بیژن آمد دمان بکوه کنابد بزه بر کمان
# Target Sentence: چو بیژن نگه کرد زان رزمگاه نبودش گذر جز بتوران سپاه
# -------------------------new test-----------------------
# Input Sentence: چو با مرغ پرنده نیرو نماند غمی گشت پرهاب خوی درنشاند
# Generated Sentence: چو با مرغ پرنده نیرو نماند غمی گشت پرهاب خوی درنشاند
# Target Sentence: نگونسار گشتند ز ابر سیاه کشان بر زمین از هوا تخت شاه
# -------------------------new test-----------------------
# Input Sentence: شما هر چه گویم ز من بشنوید اگر کار بندید خرم بوید
# Generated Sentence: شما هر چه گویم ز من بشنوید اگر کار بندید خرم بوید
# Target Sentence: یکی ژرف بین است شاه یمن که چون او نباشد به هرانجمن
# -------------------------new test-----------------------
# Input Sentence: کنند آفرین بر تو مردان من شگفته شود روی خندان من
# Generated Sentence: کنند آفرین بر تو مردان من شگفته شود روی خندان من
# Target Sentence: سیاوش بدو گفت فرمان تراست سواران و میدان و چوگان تراست
# -------------------------new test-----------------------
# Input Sentence: ولیکن همی ترسم از کردگار ز خون ریختن وز بد روزگار
# Generated Sentence: ولیکن همی ترسم از کردگار ز خون ریختن وز بد روزگار
# Target Sentence: که چندین سرنامور بی گناه جدا گردد از تن بدین رزمگاه
# -------------------------new test-----------------------
# Input Sentence: بپیش اندرون بیژن تیزچنگ همی بزمگاه آمدش جای جنگ
# Generated Sentence: بپیش اندرون بیژن تیزچنگ همی بزمگاه آمدش جای جنگ
# Target Sentence: وزان سوی با تاج بر سر تژاو که بودیش با شیر درنده تاو
# -------------------------new test-----------------------
# Input Sentence: یکی کار سازم که هر دو ز من نگیرند کین اندرین انجمن
# Generated Sentence: یکی کار سازم که هر دو ز من نگیرند کین اندرین انجمن
# Target Sentence: دو فرزند ما را کنون بر دو خیل بباید شدن تا در اردبیل
# -------------------------new test-----------------------
# Input Sentence: زنی بود برسان گردی سوار همیشه به جنگ اندرون نامدار
# Generated Sentence: زنی بود برسان گردی سوار همیشه به جنگ اندرون نامدار
# Target Sentence: کجا نام او بود گردآفرید زمانه ز مادر چنین ناورید
# -------------------------new test-----------------------
# Input Sentence: رسید این سگالش بگودرز و طوس سر سرکشان خیره گشت از فسوس
# Generated Sentence: رسید این سگالش بگودرز و طوس سر سرکشان خیره گشت از فسوس
# Target Sentence: چنین گفت با طوس گودرز پیر که ما را کنون جنگ شد ناگزیر
# -------------------------new test-----------------------
# Input Sentence: درفش از درفش و گروه از گروه گسسته نشد شب برآمد ز کوه
# Generated Sentence: درفش از درفش و گروه از گروه گسسته نشد شب برآمد ز کوه
# Target Sentence: چو شب تیره شد پیل پیش سپاه فرازآوریدند و بستند راه
# -------------------------new test-----------------------
# Input Sentence: کشیدش دوان تا بدان چاهسار دو دیده پر از خون و رخ جویبار
# Generated Sentence: کشیدش دوان تا بدان چاهسار دو دیده پر از خون و رخ جویبار
# Target Sentence: بدو گفت اینک ترا خان و مان زواری برین بسته تا جاودان
# -------------------------new test-----------------------
# Input Sentence: سپاهی و شهری همه یکسرند همه پادشاهی مرا لشکرند
# Generated Sentence: سپاهی و شهری همه یکسرند همه پادشاهی مرا لشکرند
# Target Sentence: همه در پناه جهاندار بید خردمند بید و بی آزار بید
# -------------------------new test-----------------------
# Input Sentence: بنیروی یزدان که او بد پناه بپیروز بخت جهاندار شاه
# Generated Sentence: بنیروی یزدان که او بد پناه بپیروز بخت جهاندار شاه
# Target Sentence: چو پیروز برگشت مرد از نبرد درفش دلفروز بر پای کرد
# -------------------------new test-----------------------
# Input Sentence: غمی شد دلم زانک شاه جهان چنین تیز شد با تو اندر نهان
# Generated Sentence: غمی شد دلم زانک شاه جهان چنین تیز شد با تو اندر نهان
# Target Sentence: ولیکن به گیتی به جز تاج و تخت چه جوید خردمند بیدار بخت
# -------------------------new test-----------------------
# Input Sentence: شگفت ار بمانی بدین در رواست هرآنکس که او بر جهان پادشاست
# Generated Sentence: شگفت ار بمانی بدین در رواست هرآنکس که او بر جهان پادشاست
# Target Sentence: جز از نیک نامی نباید گزید بباید چمید و بباید چرید
# -------------------------new test-----------------------
# Input Sentence: چو بشنید تور از برادر چنین به ابرو ز خشم اندر آورد چین
# Generated Sentence: چو بشنید تور از برادر چنین به ابرو ز خشم اندر آورد چین
# Target Sentence: نیامدش گفتار ایرج پسند نبد راستی نزد او ارجمند
# -------------------------new test-----------------------
# Input Sentence: چنین گفت کای کردگار ار مرا رهایی نخواهد بدن ز ایدرا
# Generated Sentence: چنین گفت کای کردگار ار مرا رهایی نخواهد بدن ز ایدرا
# Target Sentence: ز گرگین تو خواهی مگر کین من برو بشنوی درد و نفرین من
# -------------------------new test-----------------------
# Input Sentence: ازین لشکر اکنون ترا خواستست ندانم که بر دل چه آراستست
# Generated Sentence: ازین لشکر اکنون ترا خواستست ندانم که بر دل چه آراستست
# Target Sentence: برو تا ببینیش نیزه بدست تو گویی که بر کوه دارد نشست
# -------------------------new test-----------------------
# Input Sentence: اگر دیو پیش آید ار اژدها ز چنگ درازش نیابد رها
# Generated Sentence: اگر دیو پیش آید ار اژدها ز چنگ درازش نیابد رها
# Target Sentence: هزار افرین باد بر شهریار بویژه برین شیردل نامدار
# -------------------------new test-----------------------
# Input Sentence: همه موبدان رای هشیار خویش نهادند با گفت سالار خویش
# Generated Sentence: همه موبدان رای هشیار خویش نهادند با گفت سالار خویش
# Target Sentence: که ما را ز جیحون بباید گذشت زدن کوس شاهی بران پهن دشت
# -------------------------new test-----------------------
# Input Sentence: پشنگست نامش پدر شیده خواند که شیده بخورشید تابنده ماند
# Generated Sentence: پشنگست نامش پدر شیده خواند که شیده بخورشید تابنده ماند
# Target Sentence: ز گردان گردنکشان صد هزار بدو داد شاه از در کارزار
# -------------------------new test-----------------------
# Input Sentence: نشست از بر تخت زر پور زال ابا بازوی شیر و با کتف و یال
# Generated Sentence: نشست از بر تخت زر پور زال ابا بازوی شیر و با کتف و یال
# Target Sentence: به سر برش تاج و کمر بر میان سپر پیش و در دست گرز گران
# -------------------------new test-----------------------
# Input Sentence: همی داد خواهیم و زاری کنیم به خون پدر سوگواری کنیم
# Generated Sentence: همی داد خواهیم و زاری کنیم به خون پدر سوگواری کنیم
# Target Sentence: نشان فریدون بدو زنده بود زمین نعل اسپ ورا بنده بود
# -------------------------new test-----------------------
# Input Sentence: نگاریده بر برگها چهر او همه بوی مشک آمد از مهر او
# Generated Sentence: نگاریده بر برگها چهر او همه بوی مشک آمد از مهر او
# Target Sentence: بدی مه نشان بهاران بدی پرستشگه سوگواران بدی
# -------------------------new test-----------------------
# Input Sentence: برین نیز بگذشت یک چند روز گران شد فرنگیس گیتی فروز
# Generated Sentence: برین نیز بگذشت یک چند روز گران شد فرنگیس گیتی فروز
# Target Sentence: شبی قیرگون ماه پنهان شده به خواب اندرون مرغ و دام و دده
# -------------------------new test-----------------------
# Input Sentence: چنین دارم اومید از کردگار که پیروز باشی تو در کارزار
# Generated Sentence: چنین دارم اومید از کردگار که پیروز باشی تو در کارزار
# Target Sentence: همیدون گمانم که چون من ز راه بپشت سپاه اندر آرم سپاه
# -------------------------new test-----------------------
# Input Sentence: ازو نیز هم بر تنم بد رسد چپ و راست بد بینم و پیش بد
# Generated Sentence: ازو نیز هم بر تنم بد رسد چپ و راست بد بینم و پیش بد
# Target Sentence: نیاید ز سودابه خود جز بدی ندانم چه خواهد رسید ایزدی
# -------------------------new test-----------------------
# Input Sentence: بدو گفت ازین لشکر نامدار پیاده یکی مرد و چندین سوار
# Generated Sentence: بدو گفت ازین لشکر نامدار پیاده یکی مرد و چندین سوار
# Target Sentence: بایران گرازید خواهی همی سرت برفرازید خواهی همی
# -------------------------new test-----------------------
# Input Sentence: خروشید و زد دست بر سر ز شاه که شاها منم کاوهٔ دادخواه
# Generated Sentence: خروشید و زد دست بر سر ز شاه که شاها منم کاوهٔ دادخواه
# Target Sentence: یکی بی زیان مرد آهنگرم ز شاه آتش آید همی بر سرم
# -------------------------new test-----------------------
# Input Sentence: سپاه وی آسوده از رنج و تاب بمانده سپاهم چنین در شتاب
# Generated Sentence: سپاه وی آسوده از رنج و تاب بمانده سپاهم چنین در شتاب
# Target Sentence: ولیکن چنین دارم امید من که آید جهاندار خورشید من
# -------------------------new test-----------------------
# Input Sentence: یکی خط بنوشت بر پهلوی به مشکاب بر دفتر خسروی
# Generated Sentence: یکی خط بنوشت بر پهلوی به مشکاب بر دفتر خسروی
# Target Sentence: گوا بود دستان و رستم برین بزرگان لشکر همه همچنین
# -------------------------new test-----------------------
# Input Sentence: بر آتش نهم خویشتن پیش شاه گر آمرزش آرد مرا زین گناه
# Generated Sentence: بر آتش نهم خویشتن پیش شاه گر آمرزش آرد مرا زین گناه
# Target Sentence: مگر باز گردد ز بد نام من بپیران سر این بد سرانجام من
# -------------------------new test-----------------------
# Input Sentence: نبینی تو زین لشکر بیکران یکی مرد جنگی و گرزی گران
# Generated Sentence: نبینی تو زین لشکر بیکران یکی مرد جنگی و گرزی گران
# Target Sentence: که پیش من آید به آوردگاه گر ایدون که یاری دهد هور و ماه
# -------------------------new test-----------------------
# Input Sentence: گرفتش جهان پهلوان در کنار بپرسیدش از گردش روزگار
# Generated Sentence: گرفتش جهان پهلوان در کنار بپرسیدش از گردش روزگار
# Target Sentence: شه کابلستان گرفت آفرین چه بر سام و بر زال زر همچنین
# -------------------------new test-----------------------
# Input Sentence: همی رفت لشکر گروها گروه نبد دشت پیدا نه دریا نه کوه
# Generated Sentence: همی رفت لشکر گروها گروه نبد دشت پیدا نه دریا نه کوه
# Target Sentence: بفرمود پیران که بیره روید از ایدر سوی راه کوته روید
# -------------------------new test-----------------------
# Input Sentence: که در دشت مازندران یافت خوان می و جام، با میگسار جوان
# Generated Sentence: که در دشت مازندران یافت خوان می و جام، با میگسار جوان
# Target Sentence: ندانست کاو جادوی ریمنست نهفته به رنگ اندر اهریمنست
# -------------------------new test-----------------------
# Input Sentence: بیایند و بر پیش او بگذرند رد و موبد و مرزبان بشمرند
# Generated Sentence: بیایند و بر پیش او بگذرند رد و موبد و مرزبان بشمرند
# Target Sentence: برفتند و سالارشان گستهم که در جنگ شیران نبودی دژم
# -------------------------new test-----------------------
# Input Sentence: مبادا که او آید ایدر بجنگ وگر چند کاموس گردد نهنگ
# Generated Sentence: مبادا که او آید ایدر بجنگ وگر چند کاموس گردد نهنگ
# Target Sentence: نه رستم نه از سیستان لشکرست فریبرز را خاک و خون ایدرست
# -------------------------new test-----------------------
# Input Sentence: تو خوانی که ایدر مرا بنده باش به خواری به مهر من آگنده باش
# Generated Sentence: تو خوانی که ایدر مرا بنده باش به خواری به مهر من آگنده باش
# Target Sentence: ندیدست کس جفت با پیل شیر نه آتش دمان از بر و آب زیر
# -------------------------new test-----------------------
# Input Sentence: بدین چاره تا آن لب لعل فام کند آشنا با لب پور سام
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-e884e1c33705> in <cell line: 27>()
#      31     print("-------------------------new test-----------------------")
#      32     print(f"Input Sentence: {input_sentence}")
# ---> 33     generated_sentence = generate_sentence(model, tokenizer, input_sentence)
#      34     print(f"Generated Sentence: {generated_sentence}")
#      35     print(f"Target Sentence: {target_sentence}")
#
# <ipython-input-14-e884e1c33705> in generate_sentence(model, tokenizer, input_sentence, max_length, temperature)
#       4     model.eval()
#       5     with torch.no_grad():
# ----> 6         input_ids = tokenizer.encode(input_sentence, return_tensors="pt").to(device)
#       7         attention_mask = torch.zeros_like(input_ids)  # Set attention mask to 1 for all tokens
#       8         pad_token_id = tokenizer.eos_token_id  # Set pad token ID to eos_token_id for open-end generation
#
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py in encode(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, return_tensors, **kwargs)
#    2567                 method).
#    2568         """
# -> 2569         encoded_inputs = self.encode_plus(
#    2570             text,
#    2571             text_pair=text_pair,
#
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py in encode_plus(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2975         )
#    2976
# -> 2977         return self._encode_plus(
#    2978             text=text,
#    2979             text_pair=text_pair,
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/gpt2/tokenization_gpt2_fast.py in _encode_plus(self, *args, **kwargs)
#     170         )
#     171
# --> 172         return super()._encode_plus(*args, **kwargs)
#     173
#     174     def save_vocabulary(self, save_directory: str, filename_prefix: Optional[str] = None) -> Tuple[str]:
#
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_fast.py in _encode_plus(self, text, text_pair, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#     574     ) -> BatchEncoding:
#     575         batched_input = [(text, text_pair)] if text_pair else [text]
# --> 576         batched_output = self._batch_encode_plus(
#     577             batched_input,
#     578             is_split_into_words=is_split_into_words,
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/gpt2/tokenization_gpt2_fast.py in _batch_encode_plus(self, *args, **kwargs)
#     160         )
#     161
# --> 162         return super()._batch_encode_plus(*args, **kwargs)
#     163
#     164     def _encode_plus(self, *args, **kwargs) -> BatchEncoding:
#
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_fast.py in _batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose)
#     502         )
#     503
# --> 504         encodings = self._tokenizer.encode_batch(
#     505             batch_text_or_text_pairs,
#     506             add_special_tokens=add_special_tokens,
#
# KeyboardInterrupt:

# %% [markdown]
# # Since I didn't get the desirable output, I tried the LSTM model as well. This work is attached as Q3_HW4_part2.
